# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
from matplotlib.lines import Line2D
from sklearn.metrics import r2_score
import matplotlib.colors as colors
import matplotlib.cm as cmx

from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.patches as mpatches

from utils import utils

# %%
measured = pd.read_csv(r"./data/train_dm300_full.csv")
predicted = pd.read_csv(r"./data/predictions/train_dm300_backprediction.csv")
smiles_test = pd.read_csv(r"./data/predictions/smiles_test_backprediction.csv")
_removal = pd.read_csv(r"./data/test_train_dm300_full.csv")
_pred = pd.read_csv(r"./data/predictions/removal_back_pred.csv")
_final = pd.read_csv(r"./data/_FINAL_LIST.csv")

frame = {"solvent_name":measured.solvent_name, 'measured': measured.dm300, 'predicted': predicted.dm300, 'removal': _removal.dm300, "temp":_pred.dm300}

data = pd.DataFrame(frame)

# %%
for i in _final['dm300_measured']:
    if i > 1:
        print('lol')
# Out:
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol
# lol

# %%
mwco_curve = utils.rejection_diagram(x="dm300_measured", y="dm300", data=_final, x_axis="Measured", y_axis="Predicted")

# %%
mwco_curve = rejection_diagram(x="measured", y="smiles_test", data=data, x_axis="Measured", y_axis="Without solvent effect")

# %%
for enum, i in enumerate(main.dm300_measured):
    if i == "Methanol":
        print(enum)
# Out:
# 203

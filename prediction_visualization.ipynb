# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
from matplotlib.lines import Line2D
from sklearn.metrics import r2_score
import matplotlib.colors as colors
import matplotlib.cm as cmx

from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data
import matplotlib.patches as mpatches

from utils import utils

# %%
measured = pd.read_csv(r"./data/train_dm300_full.csv")
final = pd.read_csv(r"./data/predictions/FINAL_LIST_2.csv")
final.sort_values(by=['solvent_name'], inplace=True)
no_solvent = pd.read_csv(r'./data/predictions/no_solvent.csv')
no_solvent.sort_values(by=['solvent_name'], inplace=True)
frame = {'predicted':final.dm300, 'measured':final.dm300_measured, "no_solvent_measured":no_solvent.dm300_measured, "no_solvent_pred":no_solvent.dm300}

data = pd.DataFrame(frame)

# %%
mwco_curve = utils.rejection_diagram(x="dm300_measured", y="dm300", data=final, x_axis="Measured rejection (-)", y_axis="Predicted rejection (-)", save='./figures/solvent_predicted.svg')

# %%
mwco_curve = utils.rejection_diagram(x="dm300_measured", y="dm300", data=no_solvent, x_axis="Measured rejection (-)", y_axis="Predicted rejection (-)", save='./figures/no_solvent_predicted.svg')

# %%
for enum, i in enumerate(main.dm300_measured):
    if i == "Methanol":
        print(enum)
# Out:
# 203
